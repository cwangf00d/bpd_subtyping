# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tv_27_df = pd.read_csv(DATA_DIR_PATH + 'processed/full/tv_27_df.csv')
tv_df = pd.read_csv(DATA_DIR_PATH + 'processed/full/tv_df.csv')

# %%
tv_df['DSB'].value_counts()
# Out:
# 0     21755
# 1     21360
# 2     21018
# 3     20817
# 4     20707
# 5     20637
# 6     20553
# 7     20488
# 8     20412
# 9     20352
# 10    20295
# 11    20225
# 12    20161
# 13    20117
# 14    20075
# 15    20036
# 16    19999
# 17    19973
# 18    19947
# 19    19917
# 20    19888
# 21    19854
# 22    19822
# 23    19787
# 24    19744
# 25    19707
# 26    19646
# 27    19591
# Name: DSB, dtype: int64

# %%
DATA_DIR_PATH = '/Users/cindywang/PycharmProjects/bpd-subtyping/data/'

# %%
tar_df = pd.read_csv(DATA_DIR_PATH + 'processed/full/tar_df.csv')
dis_df = pd.read_csv(DATA_DIR_PATH + 'discharge_bpd_status.csv')
tardis_df = tar_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])

# %%
tardis_df.head()
# Out:
#    PatientSeqID  DSB  Label  grade_0_prob  grade_1_prob  grade_2_prob  \
# 0       5242880    0      8      0.439027      0.162121      0.138603
# 1       5242880    1      8      0.112776      0.116015      0.146353
# 2       5242880    2      8      0.062830      0.116674      0.168259
# 3       5242880    3      8      0.081345      0.170372      0.209970
# 4       5242880    4      8      0.082739      0.196281      0.264834
#
#    grade_3_prob  grade_minus1_prob  BPD Grade
# 0      0.045799           0.214450         -1
# 1      0.055306           0.569549         -1
# 2      0.058717           0.593520         -1
# 3      0.064977           0.473336         -1
# 4      0.075468           0.380677         -1

# %%
# now, something I'm interested in looking at is 
# how the probabilities predicted for risk change for the grade 3 cohort + the premature death cohort
plt.figure()
sns.lineplot(data=tardis_df, x='DSB', y='grade_minus1_prob', hue='BPD Grade')
plt.title('Trajectory of Risk Probabilities for Premature Death Outcome Given Patients of Varying BPD Grades')
plt.ylabel('Probability of Risk for Premature Death')

plt.figure()
sns.lineplot(data=tardis_df, x='DSB', y='grade_3_prob', hue='BPD Grade')
plt.title('Trajectory of Risk Probabilities for Grade 3 BPD Given Patients of Varying BPD Grades')
plt.ylabel('Probability of Risk for Grade 3 BPD')

plt.figure()
sns.lineplot(data=tardis_df, x='DSB', y='grade_2_prob', hue='BPD Grade')
plt.title('Trajectory of Risk Probabilities for Grade 2 BPD Given Patients of Varying BPD Grades')
plt.ylabel('Probability of Risk for Grade 2 BPD')

plt.figure()
sns.lineplot(data=tardis_df, x='DSB', y='grade_1_prob', hue='BPD Grade')
plt.title('Trajectory of Risk Probabilities for Grade 1 BPD Given Patients of Varying BPD Grades')
plt.ylabel('Probability of Risk for Grade 1 BPD')

plt.figure()
sns.lineplot(data=tardis_df, x='DSB', y='grade_0_prob', hue='BPD Grade')
plt.title('Trajectory of Risk Probabilities for No BPD Given Patients of Varying BPD Grades')
plt.ylabel('Probability of Risk for No BPD')
# Out:
# Text(0, 0.5, 'Probability of Risk for No BPD')

# %%
''' I also want to track how much overlap there is in the patients I found as most likely for grade 3, grade 2, 
and premature death outcomes '''

tar_df.head()
# Out:
#    PatientSeqID  DSB  Label  grade_0_prob  grade_1_prob  grade_2_prob  \
# 0       5242880    0      8      0.439027      0.162121      0.138603
# 1       5242880    1      8      0.112776      0.116015      0.146353
# 2       5242880    2      8      0.062830      0.116674      0.168259
# 3       5242880    3      8      0.081345      0.170372      0.209970
# 4       5242880    4      8      0.082739      0.196281      0.264834
#
#    grade_3_prob  grade_minus1_prob
# 0      0.045799           0.214450
# 1      0.055306           0.569549
# 2      0.058717           0.593520
# 3      0.064977           0.473336
# 4      0.075468           0.380677

# %%
t27g_d1g3_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d1g3_mr_df.csv')
t27g_d1g2_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d1g2_mr_df.csv')
t27g_d1g4_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d1g4_mr_df.csv')

t27g_d3g3_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d3g3_mr_df.csv')
t27g_d3g2_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d3g2_mr_df.csv')
t27g_d3g4_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d3g4_mr_df.csv')

t27g_d7g3_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d7g3_mr_df.csv')
t27g_d7g2_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d7g2_mr_df.csv')
t27g_d7g4_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d7g4_mr_df.csv')

t27g_d14g3_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d14g3_mr_df.csv')
t27g_d14g2_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d14g2_mr_df.csv')
t27g_d14g4_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d14g4_mr_df.csv')

t27g_d21g3_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d21g3_mr_df.csv')
t27g_d21g2_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d21g2_mr_df.csv')
t27g_d21g4_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d21g4_mr_df.csv')

t27g_d27g3_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d27g3_mr_df.csv')
t27g_d27g2_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d27g2_mr_df.csv')
t27g_d27g4_mr_df = pd.read_csv(DATA_DIR_PATH + 'processed/risk/t27g_d27g4_mr_df.csv')

# %%
len(set(list(t27g_d27g2_mr_df['PatientSeqID'])))
# Out:
# 1959

# %%
len(set(list(t27g_d1g3_mr_df['PatientSeqID'])).intersection(set(list(t27g_d1g2_mr_df['PatientSeqID']))))
# Out:
# 1166

# %%
g3_ids = set(list(t27g_d1g3_mr_df['PatientSeqID']))
g2_ids = set(list(t27g_d1g2_mr_df['PatientSeqID']))
g4_ids = set(list(t27g_d1g4_mr_df['PatientSeqID']))
print('day 1:')
print('g2-4:', len(g3_ids.intersection(g2_ids, g4_ids)))
print('g23:', len(g2_ids.intersection(g3_ids)))
print('g34:', len(g3_ids.intersection(g4_ids)))
print('g24:', len(g2_ids.intersection(g4_ids)))

g3_ids = set(list(t27g_d3g3_mr_df['PatientSeqID']))
g2_ids = set(list(t27g_d3g2_mr_df['PatientSeqID']))
g4_ids = set(list(t27g_d3g4_mr_df['PatientSeqID']))
print('day 3:')
print('g2-4:', len(g3_ids.intersection(g2_ids, g4_ids)))
print('g23:', len(g2_ids.intersection(g3_ids)))
print('g34:', len(g3_ids.intersection(g4_ids)))
print('g24:', len(g2_ids.intersection(g4_ids)))

g3_ids = set(list(t27g_d7g3_mr_df['PatientSeqID']))
g2_ids = set(list(t27g_d7g2_mr_df['PatientSeqID']))
g4_ids = set(list(t27g_d7g4_mr_df['PatientSeqID']))
print('day 7:')
print('g2-4:', len(g3_ids.intersection(g2_ids, g4_ids)))
print('g23:', len(g2_ids.intersection(g3_ids)))
print('g34:', len(g3_ids.intersection(g4_ids)))
print('g24:', len(g2_ids.intersection(g4_ids)))

g3_ids = set(list(t27g_d14g3_mr_df['PatientSeqID']))
g2_ids = set(list(t27g_d14g2_mr_df['PatientSeqID']))
g4_ids = set(list(t27g_d14g4_mr_df['PatientSeqID']))
print('day 14:')
print('g2-4:', len(g3_ids.intersection(g2_ids, g4_ids)))
print('g23:', len(g2_ids.intersection(g3_ids)))
print('g34:', len(g3_ids.intersection(g4_ids)))
print('g24:', len(g2_ids.intersection(g4_ids)))

g3_ids = set(list(t27g_d21g3_mr_df['PatientSeqID']))
g2_ids = set(list(t27g_d21g2_mr_df['PatientSeqID']))
g4_ids = set(list(t27g_d21g4_mr_df['PatientSeqID']))
print('day 21:')
print('g2-4:', len(g3_ids.intersection(g2_ids, g4_ids)))
print('g23:', len(g2_ids.intersection(g3_ids)))
print('g34:', len(g3_ids.intersection(g4_ids)))
print('g24:', len(g2_ids.intersection(g4_ids)))

g3_ids = set(list(t27g_d27g3_mr_df['PatientSeqID']))
g2_ids = set(list(t27g_d27g2_mr_df['PatientSeqID']))
g4_ids = set(list(t27g_d27g4_mr_df['PatientSeqID']))
print('day 27:')
print('g2-4:', len(g3_ids.intersection(g2_ids, g4_ids)))
print('g23:', len(g2_ids.intersection(g3_ids)))
print('g34:', len(g3_ids.intersection(g4_ids)))
print('g24:', len(g2_ids.intersection(g4_ids)))
# Out:
# day 1:
# g2-4: 135
# g23: 1166
# g34: 633
# g24: 211
# day 3:
# g2-4: 340
# g23: 1166
# g34: 976
# g24: 435
# day 7:
# g2-4: 605
# g23: 1241
# g34: 1286
# g24: 702
# day 14:
# g2-4: 928
# g23: 1343
# g34: 1528
# g24: 1052
# day 21:
# g2-4: 1091
# g23: 1462
# g34: 1576
# g24: 1205
# day 27:
# g2-4: 1197
# g23: 1555
# g34: 1578
# g24: 1285

# %%
len(set(list(t27g_d1g3_mr_df['PatientSeqID']))), len(set(list(t27g_d1g2_mr_df['PatientSeqID'])))
# Out:
# (2136, 2136)

# %%
# interested in looking at eventual distribution in top 10% cases
d1g4_counts = t27g_d1g4_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()
d1g3_counts = t27g_d1g3_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()
d1g2_counts = t27g_d1g2_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()

plt.figure()
sns.barplot(x=d1g4_counts.index, y=d1g4_counts.values/np.array(d1g4_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 1 for Premature Death Outcome')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')

plt.figure()
sns.barplot(x=d1g3_counts.index, y=d1g3_counts.values/np.array(d1g3_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 1 for Grade 3 BPD')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')

plt.figure()
sns.barplot(x=d1g2_counts.index, y=d1g2_counts.values/np.array(d1g2_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 1 for Grade 2 BPD')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')

# Day 3

# interested in looking at eventual distribution in top 10% cases
d3g4_counts = t27g_d3g4_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()
d3g3_counts = t27g_d3g3_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()
d3g2_counts = t27g_d3g2_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()

plt.figure()
sns.barplot(x=d3g4_counts.index, y=d3g4_counts.values/np.array(d3g4_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 3 for Premature Death Outcome')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')

plt.figure()
sns.barplot(x=d3g3_counts.index, y=d3g3_counts.values/np.array(d3g3_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 3 for Grade 3 BPD')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')

plt.figure()
sns.barplot(x=d3g2_counts.index, y=d3g2_counts.values/np.array(d3g2_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 3 for Grade 2 BPD')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')

# Day 7

# interested in looking at eventual distribution in top 10% cases
d7g4_counts = t27g_d7g4_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()
d7g3_counts = t27g_d7g3_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()
d7g2_counts = t27g_d7g2_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()

plt.figure()
sns.barplot(x=d7g4_counts.index, y=d7g4_counts.values/np.array(d7g4_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 7 for Premature Death Outcome')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')

plt.figure()
sns.barplot(x=d7g3_counts.index, y=d7g3_counts.values/np.array(d7g3_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 7 for Grade 3 BPD')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')

plt.figure()
sns.barplot(x=d7g2_counts.index, y=d7g2_counts.values/np.array(d7g2_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 7 for Grade 2 BPD')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')

# Day 14

# interested in looking at eventual distribution in top 10% cases
d14g4_counts = t27g_d14g4_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()
d14g3_counts = t27g_d14g3_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()
d14g2_counts = t27g_d14g2_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()

plt.figure()
sns.barplot(x=d14g4_counts.index, y=d14g4_counts.values/np.array(d14g4_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 14 for Premature Death Outcome')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')

plt.figure()
sns.barplot(x=d14g3_counts.index, y=d14g3_counts.values/np.array(d14g3_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 14 for Grade 3 BPD')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')

plt.figure()
sns.barplot(x=d14g2_counts.index, y=d14g2_counts.values/np.array(d14g2_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 14 for Grade 2 BPD')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')

# Day 21

# interested in looking at eventual distribution in top 10% cases
d21g4_counts = t27g_d21g4_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()
d21g3_counts = t27g_d21g3_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()
d21g2_counts = t27g_d21g2_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()

plt.figure()
sns.barplot(x=d21g4_counts.index, y=d21g4_counts.values/np.array(d21g4_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 21 for Premature Death Outcome')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')

plt.figure()
sns.barplot(x=d21g3_counts.index, y=d21g3_counts.values/np.array(d21g3_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 21 for Grade 3 BPD')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')

plt.figure()
sns.barplot(x=d21g2_counts.index, y=d21g2_counts.values/np.array(d21g2_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 21 for Grade 2 BPD')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')


# Day 27

# interested in looking at eventual distribution in top 10% cases
d27g4_counts = t27g_d27g4_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()
d27g3_counts = t27g_d27g3_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()
d27g2_counts = t27g_d27g2_mr_df.merge(dis_df.loc[:, ['PatientSeqID', 'BPD Grade']])['BPD Grade'].value_counts().sort_index()

plt.figure()
sns.barplot(x=d27g4_counts.index, y=d27g4_counts.values/np.array(d27g4_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 27 for Premature Death Outcome')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')

plt.figure()
sns.barplot(x=d27g3_counts.index, y=d27g3_counts.values/np.array(d27g3_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 27 for Grade 3 BPD')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')

plt.figure()
sns.barplot(x=d27g2_counts.index, y=d27g2_counts.values/np.array(d27g2_counts.values).sum())
plt.title('BPD Grade Distribution in Patients with Top 10% Probability on Day 27 for Grade 2 BPD')
plt.xlabel('BPD Grade')
plt.ylabel('% Patients')
# Out:
# Text(0, 0.5, '% Patients')
